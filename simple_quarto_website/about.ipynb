# %% [raw]
# ---
# title: "About"
# ---

# %% [markdown]
# # About this site

# %% [markdown]
# ## This site was created in the Week of September 11

# %% [markdown]
# ### Below is a plot

# %%
import random
import numpy as np
import matplotlib.pyplot as plt
x = random.sample(range(1,30),10)
y = random.sample(range(1,30),10)
plt.plot(x,y,'o')
plt.title("Random Numbers")
plt.show()
